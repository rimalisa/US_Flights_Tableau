# %%
import pandas as pd

# %%
df00 = pd.read_csv('2000.csv')

# %%
df08=pd.read_csv('2008.csv')

# %%
# append the 2000 and 2008 datasets 
df =df00.append(df08)

# %%
df.sample(50)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 491858   2000      2           6          7    555.0         600    702.0
# 5626735  2000     12           1          5   2100.0        2055   2343.0
# 3646541  2008      7          15          2   1827.0        1830   1927.0
# 1624317  2008      3          18          2   1552.0        1534   1854.0
# 5657899  2008     10           1          3    815.0         815   1003.0
# 2662237  2008      5          14          3   1815.0        1825   1958.0
# 2957583  2008      5           4          7   1442.0        1445   1649.0
# 109697   2000      1          25          2    856.0         800   1210.0
# 3922308  2008      7          22          2      NaN        1630      NaN
# 4532489  2000     10          10          2    844.0         846   1008.0
# 1052233  2008      2          14          4   1442.0        1415   1803.0
# 3143214  2000      7           6          4    831.0         835   1610.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12692775 entries, 0 to 7009727
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# ...

# %%
# write the dataframe to a csv file 
df.to_csv('flights_data.csv')

# %%
df.Year.value_counts()
# Out:
# 2008    7009728
# 2000    5683047
# Name: Year, dtype: int64
